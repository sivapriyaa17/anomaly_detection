# %% [markdown]
# # Manufacturing Log Anomaly Detection (Industry Grade) with random data

# %% [markdown]
# This project detects abnormal patterns in manufacturing tool logs using
# unsupervised learning techniques commonly used in semiconductor fabs

# %% [markdown]
# ## Techniques Used
# - Isolation Forest
# - One-Class SVM
# - Autoencoder (Deep Learning)

# %% [markdown]
# ## Manufacturing failures are rare and unlabeled. Models learn normal behavior and flag deviations.

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# E:\anamoly\venv311\Scripts\python.exe
# 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# WARNING:tensorflow:From E:\anamoly\venv311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 2.15.0

# %%
import numpy as np
import pandas as pd
np.random.seed(42)
n_samples = 10000
anomaly_ratio=0.02
data = {
    "temperature": np.random.normal(70, 5, n_samples),
    "pressure": np.random.normal(30, 3, n_samples),
    "voltage": np.random.normal(220, 10, n_samples),
    "throughput": np.random.normal(100, 8, n_samples)
}

df = pd.DataFrame(data)


idx = np.random.choice(n_samples, 200, replace=False)
n_anomalies = int(n_samples * anomaly_ratio)
df.loc[idx, "temperature"] += np.random.normal(35, 8, n_anomalies)
df.loc[idx, "pressure"] -= np.random.normal(15, 5, n_anomalies)
df.loc[idx, "voltage"] += np.random.normal(40, 10, n_anomalies)


df.head()
# Out:
#    temperature   pressure     voltage  throughput
# 0    72.483571  27.964516  223.482862   84.155424
# 1    69.308678  29.083502  222.833236   91.560115
# 2    73.238443  28.207857  210.634802   95.303773
# 3    77.615149  30.331254  225.795842  101.197351
# 4    68.829233  33.591536  205.099173  108.193299

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)
scaler
# Out:
# StandardScaler()

# %%
X_scaled
# Out:
# array([[ 0.24710198, -0.47553697,  0.24217218, -1.96428526],
#        [-0.19505183, -0.17457591,  0.18598847, -1.04278748],
#        [ 0.3522298 , -0.41008827, -0.86900742, -0.57689733],
#        ...,
#        [-0.58990679,  0.37720924, -0.49266066,  0.62131583],
#        [ 0.24644145,  1.45453097, -1.69567423,  0.81856314],
#        [ 0.34993185, -1.23515059, -0.25700045,  0.36193999]])

# %%
from sklearn.ensemble import IsolationForest

iso_forest = IsolationForest(
    n_estimators=200,
    contamination=0.02,
    random_state=42
)

iso_forest.fit(X_scaled)

df["iso_anomaly"] = iso_forest.predict(X_scaled)
df["iso_anomaly"] = df["iso_anomaly"].map({1: 0, -1: 1})

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam

input_dim = X_scaled.shape[1]

inputs = Input(shape=(input_dim,))
encoded = Dense(8, activation="relu")(inputs)
encoded = Dense(4, activation="relu")(encoded)

decoded = Dense(8, activation="relu")(encoded)
decoded = Dense(input_dim, activation="linear")(decoded)

autoencoder = Model(inputs, decoded)
autoencoder.compile(optimizer=Adam(0.001), loss="mse")

autoencoder.fit(
    X_scaled, X_scaled,
    epochs=50,
    batch_size=64,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/50
# 141/141 [==============================] - 3s 6ms/step - loss: 0.9202 - val_loss: 0.8159
# Epoch 2/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.6911 - val_loss: 0.5758
# Epoch 3/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.4819 - val_loss: 0.4074
# Epoch 4/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.3323 - val_loss: 0.2762
# Epoch 5/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.2276 - val_loss: 0.1836
# Epoch 6/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.1590 - val_loss: 0.1275
# Epoch 7/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.1046 - val_loss: 0.0748
# Epoch 8/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.0601 - val_loss: 0.0443
# Epoch 9/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.0391 - val_loss: 0.0306
# Epoch 10/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.0269 - val_loss: 0.0208
# Epoch 11/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.0188 - val_loss: 0.0147
# Epoch 12/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.0133 - val_loss: 0.0104
# Epoch 13/50
# 141/141 [==============================] - 1s 5ms/step - loss: 0.0096 - val_loss: 0.0075
# Epoch 14/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.0070 - val_loss: 0.0054
# Epoch 15/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.0052 - val_loss: 0.0040
# Epoch 16/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.0039 - val_loss: 0.0029
# Epoch 17/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.0031 - val_loss: 0.0022
# Epoch 18/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 19/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 20/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 21/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.0013 - val_loss: 7.9392e-04
# Epoch 22/50
# 141/141 [==============================] - 1s 4ms/step - loss: 0.0011 - val_loss: 6.1618e-04
# Epoch 23/50
# 141/141 [==============================] - 1s 5ms/step - loss: 9.0739e-04 - val_loss: 5.0526e-04
# Epoch 24/50
# 141/141 [==============================] - 1s 4ms/step - loss: 7.6340e-04 - val_loss: 4.0425e-04
# Epoch 25/50
# 141/141 [==============================] - 1s 4ms/step - loss: 6.5073e-04 - val_loss: 3.3191e-04
# Epoch 26/50
# 141/141 [==============================] - 1s 5ms/step - loss: 5.4734e-04 - val_loss: 2.7933e-04
# Epoch 27/50
# 141/141 [==============================] - 1s 4ms/step - loss: 4.7811e-04 - val_loss: 2.1859e-04
# Epoch 28/50
# 141/141 [==============================] - 1s 4ms/step - loss: 4.1102e-04 - val_loss: 1.8989e-04
# Epoch 29/50
# 141/141 [==============================] - 1s 5ms/step - loss: 3.5573e-04 - val_loss: 1.6444e-04
# Epoch 30/50
# 141/141 [==============================] - 1s 4ms/step - loss: 3.1046e-04 - val_loss: 1.2817e-04
# Epoch 31/50
# 141/141 [==============================] - 1s 4ms/step - loss: 2.7139e-04 - val_loss: 1.1010e-04
# Epoch 32/50
# 141/141 [==============================] - 1s 4ms/step - loss: 2.3761e-04 - val_loss: 8.8034e-05
# Epoch 33/50
# 141/141 [==============================] - 1s 5ms/step - loss: 2.0787e-04 - val_loss: 7.3955e-05
# Epoch 34/50
# 141/141 [==============================] - 1s 4ms/step - loss: 1.8155e-04 - val_loss: 6.5108e-05
# Epoch 35/50
# 141/141 [==============================] - 1s 5ms/step - loss: 1.6023e-04 - val_loss: 7.3218e-05
# Epoch 36/50
# 141/141 [==============================] - 1s 4ms/step - loss: 1.4427e-04 - val_loss: 5.4319e-05
# Epoch 37/50
# 141/141 [==============================] - 1s 4ms/step - loss: 1.2681e-04 - val_loss: 5.2028e-05
# Epoch 38/50
# 141/141 [==============================] - 1s 5ms/step - loss: 1.1331e-04 - val_loss: 3.0630e-05
# Epoch 39/50
# 141/141 [==============================] - 1s 6ms/step - loss: 9.8920e-05 - val_loss: 3.4982e-05
# Epoch 40/50
# 141/141 [==============================] - 1s 4ms/step - loss: 9.1140e-05 - val_loss: 2.7910e-05
# Epoch 41/50
# 141/141 [==============================] - 1s 5ms/step - loss: 8.1746e-05 - val_loss: 2.0722e-05
# Epoch 42/50
# 141/141 [==============================] - 1s 4ms/step - loss: 7.2660e-05 - val_loss: 2.6896e-05
# Epoch 43/50
# 141/141 [==============================] - 1s 4ms/step - loss: 6.8686e-05 - val_loss: 1.9473e-05
# Epoch 44/50
# 141/141 [==============================] - 1s 4ms/step - loss: 6.3827e-05 - val_loss: 2.2222e-05
# Epoch 45/50
# 141/141 [==============================] - 1s 4ms/step - loss: 6.3794e-05 - val_loss: 1.5266e-05
# Epoch 46/50
# 141/141 [==============================] - 1s 5ms/step - loss: 5.8459e-05 - val_loss: 1.7251e-05
# Epoch 47/50
# 141/141 [==============================] - 1s 4ms/step - loss: 4.5400e-05 - val_loss: 1.9056e-05
# Epoch 48/50
# 141/141 [==============================] - 1s 4ms/step - loss: 4.1470e-05 - val_loss: 3.5627e-05
# Epoch 49/50
# 141/141 [==============================] - 1s 4ms/step - loss: 4.2588e-05 - val_loss: 3.8529e-06
# Epoch 50/50
# 141/141 [==============================] - 1s 4ms/step - loss: 3.7484e-05 - val_loss: 6.7855e-06

# %%
reconstructions = autoencoder.predict(X_scaled)
reconstruction_error = np.mean(np.square(X_scaled - reconstructions), axis=1)

threshold = np.percentile(reconstruction_error, 98)
df["ae_anomaly"] = (reconstruction_error > threshold).astype(int)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
from sklearn.svm import OneClassSVM

ocsvm = OneClassSVM(
    kernel="rbf",
    gamma=0.05,
    nu=0.02
)

ocsvm.fit(X_scaled)

df["svm_anomaly"] = ocsvm.predict(X_scaled)
df["svm_anomaly"] = df["svm_anomaly"].map({1: 0, -1: 1})

# %%
print("Isolation Forest:", df["iso_anomaly"].sum())
print("One-Class SVM:", df["svm_anomaly"].sum())
print("Autoencoder:", df["ae_anomaly"].sum())
# Out:
# Isolation Forest: 200
# One-Class SVM: 198
# Autoencoder: 200

# %%
print(df.columns)
# Out:
# Index(['temperature', 'pressure', 'voltage', 'throughput', 'iso_anomaly',
#        'ae_anomaly', 'svm_anomaly'],
#       dtype='str')

# %%
df.to_csv("data/output.csv", index=False)

# %%
df
# Out:
#       temperature   pressure     voltage  throughput  iso_anomaly  ae_anomaly  \
# 0       72.483571  27.964516  223.482862   84.155424            0           0
# 1       69.308678  29.083502  222.833236   91.560115            0           0
# 2       73.238443  28.207857  210.634802   95.303773            0           0
# 3       77.615149  30.331254  225.795842  101.197351            0           0
# 4       68.829233  33.591536  205.099173  108.193299            0           0
# ...           ...        ...         ...         ...          ...         ...
# 9995    76.505510  31.163482  214.227121  108.957208            0           0
# 9996    60.008275  34.132100  234.446040  102.120272            0           0
# 9997    66.473416  31.135062  214.986327  104.932008            0           0
# 9998    72.478828  35.140589  201.076432  106.516988            0           0
# 9999    73.221942  25.140241  217.711158  102.847795            0           0
#
#       svm_anomaly
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 9995            0
# 9996            0
# 9997            0
# 9998            0
# 9999            0
#
# [10000 rows x 7 columns]

# %%
print("Isolation Forest anomalies:")
print(df['iso_anomaly'].value_counts())

print("\nOne-Class SVM anomalies:")
print(df['svm_anomaly'].value_counts())

print("\nAutoencoder anomalies:")
print(df['ae_anomaly'].value_counts())
# Out:
# Isolation Forest anomalies:
# iso_anomaly
# 0    9800
# 1     200
# Name: count, dtype: int64
#
# One-Class SVM anomalies:
# svm_anomaly
# 0    9802
# 1     198
# Name: count, dtype: int64
#
# Autoencoder anomalies:
# ae_anomaly
# 0    9800
# 1     200
# Name: count, dtype: int64
